# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Loy\Documents\GitHub\BC2407-Analytics-II-Project\Dataset\trafficAccident2020_cleaned.csv")
df
# Out:
#        Age Sex Person_Type Injury_Severity      Seat_Position  \
# 0       40   F      Driver           Fatal  Front_Seat_Driver
# 1       28   F      Driver           Light  Front_Seat_Driver
# 2       48   M      Driver           Light  Front_Seat_Driver
# 3       18   M      Driver           Light  Front_Seat_Driver
# 4       36   M      Driver           Light  Front_Seat_Driver
# ...    ...  ..         ...             ...                ...
# 20198   17   M      Driver           Fatal  Front_Seat_Driver
# 20199   89   M      Driver           Fatal  Front_Seat_Driver
# 20200   21   M      Driver           Light  Front_Seat_Driver
# 20201   84   M      Driver           Fatal  Front_Seat_Driver
# 20202   18   F      Driver           Light  Front_Seat_Driver
#
#       Restraint_Equipment_Usage        Airbag    Drugs  Non_Motorist_Location  \
# 0                  No_Restraint  Not_Deployed  Unknown                      0
# 1         Shoulder_And_Lap_Belt  Not_Deployed       No                      0
# 2         Shoulder_And_Lap_Belt  Not_Deployed       No                      0
# 3         Shoulder_And_Lap_Belt  Not_Deployed       No                      0
# 4                       Unknown       Unknown  Unknown                      0
# ...                         ...           ...      ...                    ...
# 20198     Shoulder_And_Lap_Belt      Deployed       No                      0
# 20199              No_Restraint  Not_Deployed       No                      0
# 20200     Shoulder_And_Lap_Belt  Not_Deployed       No                      0
# 20201                   Unknown      Deployed       No                      0
# 20202                  Lap_Belt      Deployed       No                      0
#
#        Num_Of_Occupants  ... Month Day_Of_Week Hour      Harmful_Event  \
# 0                     2  ...     1           5   17      Motor_Vehicle
# 1                     1  ...     1           3   19         Pedestrian
# 2                     1  ...     1           7   21      Motor_Vehicle
# 3                     1  ...     1           2   22         Pedestrian
# 4                     1  ...     1           2   17      Pedalcyclists
# ...                 ...  ...   ...         ...  ...                ...
# 20198                 1  ...     9           7   21      Motor_Vehicle
# 20199                 1  ...     8           5    9      Motor_Vehicle
# 20200                 1  ...     9           4   14         Pedestrian
# 20201                 1  ...    11           2   15  Static_Structures
# 20202                 2  ...    12           3   20      Motor_Vehicle
#
#        Relation_To_Junction  Type_Of_Intersection  Location_Of_Crash  \
# 0              Non_Junction      Not_Intersection         On_Roadway
# 1              Intersection                 4_Way         On_Roadway
# 2              Intersection                 4_Way         On_Roadway
# 3              Non_Junction      Not_Intersection         On_Roadway
# 4              Non_Junction      Not_Intersection         On_Roadway
# ...                     ...                   ...                ...
# 20198          Non_Junction      Not_Intersection         On_Roadway
# 20199          Intersection                 4_Way         On_Roadway
# 20200       Driveway_Access      Not_Intersection         On_Roadway
# 20201          Non_Junction      Not_Intersection        Off_Roadway
# 20202          Non_Junction      Not_Intersection         On_Roadway
#
#        Light_Condition Weather Fatality_Rate
# 0         Medium_Light    Rain     16.666667
# 1         Medium_Light   Clear     50.000000
# 2         Medium_Light   Clear     50.000000
# 3            Low_Light  Cloudy     50.000000
# 4         Medium_Light  Cloudy     50.000000
# ...                ...     ...           ...
# 20198        Low_Light   Clear     33.333333
# 20199       High_Light   Clear      9.090909
# 20200       High_Light   Clear     50.000000
# 20201       High_Light   Clear    100.000000
# 20202        Low_Light   Clear     25.000000
#
# [20203 rows x 41 columns]

# %%
df.describe()
# Out:
#                 Age  Non_Motorist_Location  Num_Of_Occupants  Travel_Speed  \
# count  20203.000000                20203.0      20203.000000  20203.000000
# mean      40.458447                    0.0          1.375241     81.831550
# std       17.479361                    0.0          0.843521     27.578026
# min        4.000000                    0.0          1.000000      0.000000
# 25%       27.000000                    0.0          1.000000     72.420300
# 50%       36.000000                    0.0          1.000000     72.420300
# 75%       52.000000                    0.0          1.000000    104.607100
# max      100.000000                    0.0         27.000000    241.401000
#
#        Driver_Height  Driver_Weight  Previous_Speed_Convictions  Num_Of_Lanes  \
# count   20203.000000   20203.000000                20203.000000  20203.000000
# mean        1.743747      82.226624                    0.258229      2.931297
# std         0.087579      14.982658                    0.682703      1.190719
# min         0.914402      20.408163                    0.000000      1.000000
# 25%         1.701803      79.365079                    0.000000      2.000000
# 50%         1.752604      81.179138                    0.000000      2.000000
# 75%         1.803404      81.632653                    0.000000      4.000000
# max         2.159004     217.687075                    9.000000      5.000000
#
#                 Day         Month   Day_Of_Week          Hour  Fatality_Rate
# count  20203.000000  20203.000000  20203.000000  20203.000000   20203.000000
# mean      15.662575      6.898035      4.107410     13.300698      54.459950
# std        8.844684      3.378141      2.072765      7.262990      26.754466
# min        1.000000      1.000000      1.000000      0.000000       3.571429
# 25%        8.000000      4.000000      2.000000      7.000000      33.333333
# 50%       16.000000      7.000000      4.000000     15.000000      50.000000
# 75%       23.000000     10.000000      6.000000     20.000000      50.000000
# max       31.000000     12.000000      7.000000     23.000000     100.000000

# %%
plt.hist(df['Fatality_Rate'], bins=50, edgecolor='black')
plt.title('Distribution of Fatality_Rate')
plt.show()

# %%
df.boxplot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
df.boxplot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
grouped_data = df.groupby("Travel_Speed").mean()["Fatality_Rate"]
plt.plot(grouped_data.index, grouped_data.values)
plt.title("Fatality Rate against Travel Speed")
plt.xlabel("Travel Speed") # Set y-axis limits from 0 to 10
# Out:
# Text(0.5, 0, 'Travel Speed')

# %%
grouped_data = df.groupby("Day_Of_Week").mean()["Num_Of_Occupants"]
plt.plot(grouped_data.index, grouped_data.values,marker='o')
plt.title("Mean Num of Occupants Per Day of Week")
plt.xlabel("Day of Week")
plt.ylim(bottom=1, top=2)  # Set y-axis limits from 0 to 10
for x, y in zip(grouped_data.index, grouped_data.values):
    plt.text(x, y, str(round(y, 2)), ha='center', va='bottom')

# %%
plt.hist(df['Fatality_Rate'], bins=50, edgecolor='black')
plt.title('Distribution of Fatality_Rate')
plt.show()

# %%
grouped_data = df.groupby("Num_Of_Lanes").mean()["Fatality_Rate"]
plt.plot(grouped_data.index, grouped_data.values,marker='o')
plt.title("Mean Fatality Rate per Num Of Lanes")
plt.xlabel("Fatality Rate")
plt.ylim(bottom=1, top=2)  # Set y-axis limits from 0 to 10
for x, y in zip(grouped_data.index, grouped_data.values):
    plt.text(x, y, str(round(y, 2)), ha='center', va='bottom')

# %%
fatal= df[df['Fatality_Rate']==100]

# %%
fatal.describe()
# Out:
#                Age  Non_Motorist_Location  Num_Of_Occupants  Travel_Speed  \
# count  4503.000000                 4503.0       4503.000000   4503.000000
# mean     41.393293                    0.0          1.057517     91.580131
# std      17.646376                    0.0          0.274854     26.592626
# min      10.000000                    0.0          1.000000      0.000000
# 25%      27.000000                    0.0          1.000000     72.420300
# 50%      37.000000                    0.0          1.000000     72.420300
# 75%      55.000000                    0.0          1.000000    112.653800
# max      99.000000                    0.0          5.000000    225.307600
#
#        Driver_Height  Driver_Weight  Previous_Speed_Convictions  Num_Of_Lanes  \
# count    4503.000000    4503.000000                 4503.000000   4503.000000
# mean        1.754375      83.279124                    0.290251      2.546302
# std         0.085887      15.622454                    0.705006      1.013689
# min         0.914402      20.408163                    0.000000      1.000000
# 25%         1.701803      79.365079                    0.000000      2.000000
# 50%         1.752604      81.179138                    0.000000      2.000000
# 75%         1.803404      86.167800                    0.000000      3.000000
# max         2.032004     206.349206                    7.000000      5.000000
#
#                Day        Month  Day_Of_Week         Hour  Fatality_Rate
# count  4503.000000  4503.000000  4503.000000  4503.000000         4503.0
# mean     15.743726     6.900955     4.057295    12.013769          100.0
# std       8.880397     3.324379     2.169987     7.729822            0.0
# min       1.000000     1.000000     1.000000     0.000000          100.0
# 25%       8.000000     4.000000     2.000000     4.000000          100.0
# 50%      16.000000     7.000000     4.000000    13.000000          100.0
# 75%      23.000000    10.000000     6.000000    19.000000          100.0
# max      31.000000    12.000000     7.000000    23.000000          100.0

# %%
df.describe()
# Out:
#                 Age  Non_Motorist_Location  Num_Of_Occupants  Travel_Speed  \
# count  20203.000000                20203.0      20203.000000  20203.000000
# mean      40.458447                    0.0          1.375241     81.831550
# std       17.479361                    0.0          0.843521     27.578026
# min        4.000000                    0.0          1.000000      0.000000
# 25%       27.000000                    0.0          1.000000     72.420300
# 50%       36.000000                    0.0          1.000000     72.420300
# 75%       52.000000                    0.0          1.000000    104.607100
# max      100.000000                    0.0         27.000000    241.401000
#
#        Driver_Height  Driver_Weight  Previous_Speed_Convictions  Num_Of_Lanes  \
# count   20203.000000   20203.000000                20203.000000  20203.000000
# mean        1.743747      82.226624                    0.258229      2.931297
# std         0.087579      14.982658                    0.682703      1.190719
# min         0.914402      20.408163                    0.000000      1.000000
# 25%         1.701803      79.365079                    0.000000      2.000000
# 50%         1.752604      81.179138                    0.000000      2.000000
# 75%         1.803404      81.632653                    0.000000      4.000000
# max         2.159004     217.687075                    9.000000      5.000000
#
#                 Day         Month   Day_Of_Week          Hour  Fatality_Rate
# count  20203.000000  20203.000000  20203.000000  20203.000000   20203.000000
# mean      15.662575      6.898035      4.107410     13.300698      54.459950
# std        8.844684      3.378141      2.072765      7.262990      26.754466
# min        1.000000      1.000000      1.000000      0.000000       3.571429
# 25%        8.000000      4.000000      2.000000      7.000000      33.333333
# 50%       16.000000      7.000000      4.000000     15.000000      50.000000
# 75%       23.000000     10.000000      6.000000     20.000000      50.000000
# max       31.000000     12.000000      7.000000     23.000000     100.000000
